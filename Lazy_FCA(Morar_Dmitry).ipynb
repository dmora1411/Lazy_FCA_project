# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns
pd.set_option('display.max_columns', None)
from sklearn.model_selection import train_test_split
from typing import Any, List, Dict, Tuple
from sklearn.metrics import f1_score, accuracy_score

# %% [markdown]
# # 1. Loading the dataset

# %%
df = pd.read_csv('car_prices.csv', sep=',')
df.head(10)
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 0              Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2       Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3     Datsun RediGO T Option  2017         250000      46000  Petrol
# 4      Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5       Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6  Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7   Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8   Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9   Maruti Celerio Green VXI  2017         365000      78000     CNG
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner
# 5  Individual       Manual   First Owner
# 6  Individual       Manual   First Owner
# 7  Individual       Manual  Second Owner
# 8  Individual       Manual   First Owner
# 9  Individual       Manual   First Owner

# %% [markdown]
# # 2. Preparing the data

# %% [markdown]
# **2.1 Consider the column with the brand and model of the car, select only the brand from there, in the category 'Other' we define the brands, the amount of data for which is less than 1% of the entire dataset. In the 'fuel' column, the main categorical values are 'Petrol' and 'Diesel', the other values, which are very few, are defined as 'Other'. We conduct a binarization of these attributes and some others in the form of a nominal scale**

# %%
df['brand'] = df['name'].str.split().str[0]
total_records = len(df)


threshold = total_records * 0.01


brand_counts = df['brand'].value_counts()


rare_brands = brand_counts[brand_counts < threshold].index

df['brand'] = df['brand'].replace(rare_brands, 'Other')

df.drop('name', axis=1, inplace=True)
df['fuel'] = df['fuel'].replace(['CNG', 'LPG', 'Electric'], 'Other')
columns_to_encode = ['brand', 'owner', 'transmission', 'seller_type', 'fuel']
dummies = pd.get_dummies(df[columns_to_encode], prefix=columns_to_encode, drop_first=False)


df = pd.concat([df, dummies], axis=1)


df = df.drop(columns=columns_to_encode)

# %% [markdown]
# **2.2 We look at 25, 50, 75 percentiles on the 'year' and 'km_driven' attributes to understand the bounds on which we will binarize in the inter-ordinal scale form. Next, we binarize the given attributes.**

# %%
km_percentiles = np.percentile(df['km_driven'], [25, 50, 75])


df['km_category'] = pd.cut(
    df['km_driven'],
    bins=[0, km_percentiles[0], km_percentiles[1], km_percentiles[2], df['km_driven'].max()],
    labels=[f'<{km_percentiles[0]}', f'{km_percentiles[0]}-{km_percentiles[1]}', f'{km_percentiles[1]}-{km_percentiles[2]}', f'>{km_percentiles[2]}']
)

year_percentiles = np.percentile(df['year'], [25, 50, 75])


df['year_category'] = pd.cut(
    df['year'],
    bins=[0, year_percentiles[0], year_percentiles[1], year_percentiles[2], df['year'].max()],
    labels=[f'<{year_percentiles[0]}', f'{year_percentiles[0]}-{year_percentiles[1]}', f'{year_percentiles[1]}-{year_percentiles[2]}', f'>{year_percentiles[2]}']
)

dummies1 = pd.get_dummies(df[['year_category', 'km_category']], prefix = ['year', 'km'], drop_first=False)

# Adding dummies to the original DataFrame
df = pd.concat([df, dummies1], axis=1)

# Delete the original columns
df = df.drop(columns=['year', 'year_category', 'km_category', 'km_driven'])

# %% [markdown]
# **2.3 Since there is no classification of the targeting variable (car price) in the original dataset, we will do it ourselves by dividing car prices into 2 classes (0-Low, 1-High)**

# %%
df['price_class'] = pd.qcut(df['selling_price'], q=2, labels=[0, 1])

# %%
df['price_class'].value_counts()
# Out:
# price_class
# 0    2174
# 1    2166
# Name: count, dtype: int64

# %%
df.drop('selling_price', axis=1, inplace=True)

# %%
df.corr()['price_class']
# Out:
# brand_Audi                      0.118619
# brand_Chevrolet                -0.158068
# brand_Ford                      0.059145
# brand_Honda                     0.091100
# brand_Hyundai                  -0.007935
# brand_Mahindra                  0.122599
# brand_Maruti                   -0.139277
# brand_Nissan                    0.026988
# brand_Other                     0.052991
# brand_Renault                   0.028459
# brand_Skoda                     0.052183
# brand_Tata                     -0.152135
# brand_Toyota                    0.134782
# brand_Volkswagen                0.025553
# owner_First Owner               0.303510
# owner_Fourth & Above Owner     -0.113818
# owner_Second Owner             -0.212538
# owner_Test Drive Car            0.062825
# owner_Third Owner              -0.158386
# transmission_Automatic          0.256597
# transmission_Manual            -0.256597
# seller_type_Dealer              0.196211
# seller_type_Individual         -0.241846
# seller_type_Trustmark Dealer    0.149341
# fuel_Diesel                     0.324881
# fuel_Other                     -0.076238
# fuel_Petrol                    -0.306564
# year_<2011.0                   -0.523287
# year_2011.0-2014.0             -0.022780
# year_2014.0-2016.0              0.199095
# year_>2016.0                    0.404055
# km_<35000.0                     0.257871
# km_35000.0-60000.0             -0.003548
# km_60000.0-90000.0             -0.116327
# km_>90000.0                    -0.151127
# price_class                     1.000000
# Name: price_class, dtype: float64

# %% [markdown]
# **2.4 Split the data on train and test samples**

# %%
X = df.drop('price_class', axis=1)
y = df['price_class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# # 3. Lazy FCA classification:

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
class LazyClassifierFCA:
    def __init__(self):
        self.X_train = None
        self.y_train = None

    def fit(self, X_train: pd.DataFrame, y_train: pd.Series) -> None:
        self.X_train = X_train
        self.y_train = y_train
        
    def classify_sample(self, sample: pd.Series) -> Any:
        # Split X_train into positive and negative classes
        X_train_positive = self.X_train[y_train == 1]
        X_train_negative = self.X_train[y_train == 0]
        
        positive_classifiers = 0
        negative_classifiers = 0
        
        # Function to check if intersection with a train sample is a positive classifier
        def is_positive_classifier(intersection):
            # Find samples in X_train_positive that contain the intersection
            num_positive = ((X_train_positive | ~intersection) == True).all(axis=1).sum()
            num_negative = ((X_train_negative | ~intersection) == True).all(axis=1).sum()
            return num_negative == 0 and num_positive > 1
        
        # Function to check if intersection is a negative classifier
        def is_negative_classifier(intersection):
            # Find samples in X_train_negative that contain the intersection
            num_positive = ((X_train_positive | ~intersection) == True).all(axis=1).sum()
            num_negative = ((X_train_negative | ~intersection) == True).all(axis=1).sum()
            return num_positive == 0 and num_negative > 1
        
        # Check for positive classifiers by intersecting sample with each positive object
        for _, pos_sample in X_train_positive.iterrows():
            intersection = sample & pos_sample
            if is_positive_classifier(intersection):
                positive_classifiers += 1

        # Check for negative classifiers by intersecting sample with each negative object
        for _, neg_sample in X_train_negative.iterrows():
            intersection = sample & neg_sample
            if is_negative_classifier(intersection):
                negative_classifiers += 1

        # Determine the class based on the number of classifiers
        if positive_classifiers > negative_classifiers:
            print(f"sample {sample.name} is classified as 1, {positive_classifiers=}, {negative_classifiers=}")
            return 1  # Predict positive
            
        elif negative_classifiers > positive_classifiers:
            print(f"sample {sample.name} is classified as 0, {positive_classifiers=}, {negative_classifiers=}")
            return 0  # Predict negative

        else:
            # If equal, you can decide on a rule, like defaulting to 0 or 1, or returning 'undetermined'
            print(f"sample {sample.name} is classified as 1, default, {positive_classifiers=}, {negative_classifiers=}")
        
            return 1  # or 0, depending on the choice


    def predict(self, X_test: pd.DataFrame) -> List[Any]:
        # List to store predictions for each test sample
        predictions = []
        
        # Iterate through each sample in X_test
        for _, sample in X_test.iterrows():
            # Classify the sample and append the result to predictions
            prediction = self.classify_sample(sample)
            predictions.append(prediction)
        
        return predictions

# %%
sample = X_test.iloc[1]
y.iloc[1]
# Out:
# 0

# %%
len(X_train[y_train == 1]), len(X_train[y_train == 0])
# Out:
# (1733, 1739)

# %%
pos_X_train = X_train[y_train == 1]
neg_X_train = X_train[y_train == 0]
len(pos_X_train), len(neg_X_train)
# Out:
# (1733, 1739)

# %%
classifier = LazyClassifierFCA()
classifier.fit(X_train, y_train)

# %%
classifier.classify_sample(sample)
# Out:
# sample 1018 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# 1

# %%
y_pred = classifier.predict(X_test)
# Out:
# sample 1944 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1018 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2071 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3726 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2448 is classified as 1, positive_classifiers=153, negative_classifiers=0
# sample 3681 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 513 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 807 is classified as 1, positive_classifiers=88, negative_classifiers=0
# sample 830 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2639 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3069 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 185 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 3853 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1425 is classified as 1, positive_classifiers=33, negative_classifiers=3
# sample 839 is classified as 1, positive_classifiers=70, negative_classifiers=0
# sample 2871 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3330 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2262 is classified as 1, positive_classifiers=67, negative_classifiers=0
# sample 3301 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2388 is classified as 1, positive_classifiers=25, negative_classifiers=0
# sample 3050 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 595 is classified as 0, positive_classifiers=0, negative_classifiers=14
# sample 2375 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1641 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3214 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1028 is classified as 1, positive_classifiers=67, negative_classifiers=0
# sample 3998 is classified as 0, positive_classifiers=0, negative_classifiers=24
# sample 801 is classified as 0, positive_classifiers=0, negative_classifiers=157
# sample 3696 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1514 is classified as 1, positive_classifiers=18, negative_classifiers=0
# sample 1190 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 637 is classified as 1, positive_classifiers=95, negative_classifiers=0
# sample 1669 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3042 is classified as 1, positive_classifiers=45, negative_classifiers=0
# sample 1760 is classified as 0, positive_classifiers=3, negative_classifiers=152
# sample 2116 is classified as 0, positive_classifiers=0, negative_classifiers=104
# sample 2814 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3942 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2432 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4031 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3508 is classified as 0, positive_classifiers=0, negative_classifiers=53
# sample 1960 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3679 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2510 is classified as 1, positive_classifiers=65, negative_classifiers=0
# sample 3662 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1155 is classified as 1, positive_classifiers=63, negative_classifiers=0
# sample 3888 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3800 is classified as 0, positive_classifiers=0, negative_classifiers=16
# sample 2476 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 4213 is classified as 1, positive_classifiers=5, negative_classifiers=0
# sample 2782 is classified as 1, positive_classifiers=292, negative_classifiers=0
# sample 4338 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 487 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2049 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2204 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1270 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4108 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3682 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1642 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1345 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 3535 is classified as 1, positive_classifiers=16, negative_classifiers=0
# sample 4092 is classified as 1, positive_classifiers=17, negative_classifiers=0
# sample 2834 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 93 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2524 is classified as 0, positive_classifiers=0, negative_classifiers=5
# sample 1337 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 281 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4254 is classified as 1, positive_classifiers=323, negative_classifiers=0
# sample 239 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2743 is classified as 1, positive_classifiers=67, negative_classifiers=0
# sample 21 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2965 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2155 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2280 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1139 is classified as 0, positive_classifiers=0, negative_classifiers=44
# sample 4290 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 3121 is classified as 1, positive_classifiers=8, negative_classifiers=0
# sample 4308 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 43 is classified as 1, positive_classifiers=112, negative_classifiers=0
# sample 2832 is classified as 1, positive_classifiers=217, negative_classifiers=0
# sample 25 is classified as 1, positive_classifiers=38, negative_classifiers=0
# sample 1952 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3806 is classified as 1, positive_classifiers=61, negative_classifiers=0
# sample 674 is classified as 0, positive_classifiers=0, negative_classifiers=9
# sample 469 is classified as 1, positive_classifiers=10, negative_classifiers=0
# sample 2189 is classified as 1, positive_classifiers=45, negative_classifiers=0
# sample 2621 is classified as 0, positive_classifiers=0, negative_classifiers=160
# sample 312 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 556 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 3242 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 646 is classified as 0, positive_classifiers=0, negative_classifiers=14
# sample 1911 is classified as 1, positive_classifiers=159, negative_classifiers=0
# sample 4040 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2885 is classified as 0, positive_classifiers=0, negative_classifiers=75
# sample 3401 is classified as 0, positive_classifiers=0, negative_classifiers=10
# sample 1233 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 935 is classified as 1, positive_classifiers=97, negative_classifiers=0
# sample 1633 is classified as 0, positive_classifiers=0, negative_classifiers=25
# sample 2352 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2483 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1205 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3195 is classified as 1, positive_classifiers=2, negative_classifiers=0
# sample 1565 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 2976 is classified as 1, positive_classifiers=41, negative_classifiers=0
# sample 493 is classified as 0, positive_classifiers=0, negative_classifiers=12
# sample 3979 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 759 is classified as 1, positive_classifiers=18, negative_classifiers=0
# sample 384 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 547 is classified as 1, positive_classifiers=77, negative_classifiers=0
# sample 499 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1437 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2213 is classified as 1, positive_classifiers=57, negative_classifiers=0
# sample 82 is classified as 0, positive_classifiers=0, negative_classifiers=96
# sample 929 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3244 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 718 is classified as 1, positive_classifiers=11, negative_classifiers=0
# sample 3168 is classified as 0, positive_classifiers=0, negative_classifiers=18
# sample 416 is classified as 0, positive_classifiers=0, negative_classifiers=57
# sample 2386 is classified as 0, positive_classifiers=0, negative_classifiers=3
# sample 891 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 254 is classified as 1, positive_classifiers=114, negative_classifiers=0
# sample 2462 is classified as 1, positive_classifiers=12, negative_classifiers=0
# sample 1991 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1333 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 501 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2716 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 623 is classified as 1, positive_classifiers=110, negative_classifiers=0
# sample 3766 is classified as 0, positive_classifiers=0, negative_classifiers=38
# sample 1124 is classified as 0, positive_classifiers=0, negative_classifiers=22
# sample 4247 is classified as 0, positive_classifiers=0, negative_classifiers=30
# sample 3776 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 1645 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4070 is classified as 0, positive_classifiers=0, negative_classifiers=135
# sample 611 is classified as 1, positive_classifiers=65, negative_classifiers=0
# sample 2253 is classified as 1, positive_classifiers=75, negative_classifiers=0
# sample 1368 is classified as 0, positive_classifiers=0, negative_classifiers=35
# sample 3695 is classified as 1, positive_classifiers=9, negative_classifiers=0
# sample 1417 is classified as 1, positive_classifiers=77, negative_classifiers=0
# sample 614 is classified as 0, positive_classifiers=0, negative_classifiers=14
# sample 306 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3646 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2374 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1795 is classified as 1, positive_classifiers=73, negative_classifiers=0
# sample 2933 is classified as 0, positive_classifiers=0, negative_classifiers=5
# sample 2977 is classified as 0, positive_classifiers=0, negative_classifiers=6
# sample 916 is classified as 1, positive_classifiers=35, negative_classifiers=0
# sample 2472 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3522 is classified as 0, positive_classifiers=0, negative_classifiers=2
# sample 3172 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3290 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4079 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3266 is classified as 1, positive_classifiers=98, negative_classifiers=0
# sample 3359 is classified as 0, positive_classifiers=0, negative_classifiers=110
# sample 2959 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1039 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4084 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 1848 is classified as 0, positive_classifiers=0, negative_classifiers=61
# sample 833 is classified as 0, positive_classifiers=0, negative_classifiers=91
# sample 4313 is classified as 1, positive_classifiers=300, negative_classifiers=0
# sample 662 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2249 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1061 is classified as 0, positive_classifiers=0, negative_classifiers=279
# sample 2573 is classified as 0, positive_classifiers=0, negative_classifiers=6
# sample 877 is classified as 0, positive_classifiers=0, negative_classifiers=53
# sample 691 is classified as 1, positive_classifiers=11, negative_classifiers=0
# sample 4046 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 2281 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1427 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3901 is classified as 1, positive_classifiers=204, negative_classifiers=0
# sample 57 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 585 is classified as 1, positive_classifiers=110, negative_classifiers=0
# sample 536 is classified as 1, positive_classifiers=30, negative_classifiers=16
# sample 3054 is classified as 1, positive_classifiers=95, negative_classifiers=0
# sample 3790 is classified as 1, positive_classifiers=223, negative_classifiers=0
# sample 1011 is classified as 0, positive_classifiers=0, negative_classifiers=102
# sample 2142 is classified as 0, positive_classifiers=0, negative_classifiers=16
# sample 1639 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2314 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 4144 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3319 is classified as 1, positive_classifiers=23, negative_classifiers=0
# sample 1990 is classified as 0, positive_classifiers=0, negative_classifiers=16
# sample 3012 is classified as 0, positive_classifiers=0, negative_classifiers=37
# sample 516 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1622 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 129 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2512 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2063 is classified as 1, positive_classifiers=271, negative_classifiers=0
# sample 368 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 840 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2751 is classified as 0, positive_classifiers=0, negative_classifiers=61
# sample 1159 is classified as 0, positive_classifiers=0, negative_classifiers=3
# sample 475 is classified as 0, positive_classifiers=0, negative_classifiers=12
# sample 3643 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2964 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2974 is classified as 0, positive_classifiers=0, negative_classifiers=168
# sample 2430 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1600 is classified as 0, positive_classifiers=0, negative_classifiers=132
# sample 3323 is classified as 0, positive_classifiers=0, negative_classifiers=102
# sample 976 is classified as 1, positive_classifiers=245, negative_classifiers=0
# sample 1535 is classified as 1, positive_classifiers=2, negative_classifiers=0
# sample 3764 is classified as 1, positive_classifiers=8, negative_classifiers=0
# sample 2216 is classified as 1, positive_classifiers=49, negative_classifiers=0
# sample 887 is classified as 1, positive_classifiers=8, negative_classifiers=0
# sample 847 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 776 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 147 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3328 is classified as 0, positive_classifiers=0, negative_classifiers=84
# sample 4033 is classified as 0, positive_classifiers=0, negative_classifiers=38
# sample 1272 is classified as 1, positive_classifiers=3, negative_classifiers=2
# sample 728 is classified as 1, positive_classifiers=24, negative_classifiers=8
# sample 2734 is classified as 0, positive_classifiers=0, negative_classifiers=181
# sample 85 is classified as 1, positive_classifiers=217, negative_classifiers=0
# sample 4050 is classified as 0, positive_classifiers=0, negative_classifiers=35
# sample 1156 is classified as 1, positive_classifiers=285, negative_classifiers=0
# sample 2853 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4093 is classified as 1, positive_classifiers=5, negative_classifiers=0
# sample 4226 is classified as 1, positive_classifiers=3, negative_classifiers=0
# sample 2854 is classified as 0, positive_classifiers=0, negative_classifiers=100
# sample 2306 is classified as 0, positive_classifiers=0, negative_classifiers=100
# sample 2627 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 771 is classified as 1, positive_classifiers=163, negative_classifiers=0
# sample 2390 is classified as 0, positive_classifiers=0, negative_classifiers=135
# sample 2219 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3170 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3402 is classified as 1, positive_classifiers=235, negative_classifiers=0
# sample 289 is classified as 1, positive_classifiers=300, negative_classifiers=0
# sample 3691 is classified as 0, positive_classifiers=0, negative_classifiers=3
# sample 1787 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3466 is classified as 0, positive_classifiers=0, negative_classifiers=70
# sample 2914 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4245 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3469 is classified as 0, positive_classifiers=0, negative_classifiers=84
# sample 2409 is classified as 0, positive_classifiers=0, negative_classifiers=44
# sample 4016 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 4209 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1977 is classified as 1, positive_classifiers=300, negative_classifiers=0
# sample 7 is classified as 0, positive_classifiers=0, negative_classifiers=24
# sample 2813 is classified as 1, positive_classifiers=67, negative_classifiers=0
# sample 1500 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1786 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1808 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 701 is classified as 1, positive_classifiers=48, negative_classifiers=0
# sample 974 is classified as 1, positive_classifiers=245, negative_classifiers=0
# sample 4118 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4187 is classified as 1, positive_classifiers=6, negative_classifiers=0
# sample 3052 is classified as 0, positive_classifiers=0, negative_classifiers=5
# sample 3248 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 2046 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 216 is classified as 1, positive_classifiers=95, negative_classifiers=0
# sample 3794 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1711 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 3876 is classified as 1, positive_classifiers=38, negative_classifiers=0
# sample 4263 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1221 is classified as 0, positive_classifiers=0, negative_classifiers=77
# sample 3968 is classified as 0, positive_classifiers=0, negative_classifiers=2
# sample 2583 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1766 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2107 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 34 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 3156 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 480 is classified as 0, positive_classifiers=0, negative_classifiers=84
# sample 2078 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3684 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 1461 is classified as 1, positive_classifiers=24, negative_classifiers=0
# sample 3937 is classified as 1, positive_classifiers=45, negative_classifiers=0
# sample 940 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1841 is classified as 1, positive_classifiers=67, negative_classifiers=0
# sample 2591 is classified as 1, positive_classifiers=29, negative_classifiers=2
# sample 1857 is classified as 1, positive_classifiers=41, negative_classifiers=0
# sample 2780 is classified as 0, positive_classifiers=0, negative_classifiers=279
# sample 2082 is classified as 0, positive_classifiers=0, negative_classifiers=70
# sample 1555 is classified as 0, positive_classifiers=0, negative_classifiers=153
# sample 3572 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2292 is classified as 0, positive_classifiers=0, negative_classifiers=32
# sample 14 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 3261 is classified as 1, positive_classifiers=163, negative_classifiers=0
# sample 3694 is classified as 1, positive_classifiers=28, negative_classifiers=0
# sample 2179 is classified as 1, positive_classifiers=67, negative_classifiers=0
# sample 859 is classified as 0, positive_classifiers=0, negative_classifiers=73
# sample 2020 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 854 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1013 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 867 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 3637 is classified as 1, positive_classifiers=52, negative_classifiers=0
# sample 1594 is classified as 0, positive_classifiers=0, negative_classifiers=99
# sample 1249 is classified as 1, positive_classifiers=17, negative_classifiers=0
# sample 1236 is classified as 0, positive_classifiers=0, negative_classifiers=293
# sample 3181 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 841 is classified as 0, positive_classifiers=0, negative_classifiers=106
# sample 1837 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 3563 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 418 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 377 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 870 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2842 is classified as 1, positive_classifiers=147, negative_classifiers=0
# sample 4244 is classified as 1, positive_classifiers=133, negative_classifiers=0
# sample 1380 is classified as 0, positive_classifiers=0, negative_classifiers=39
# sample 2906 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1070 is classified as 1, positive_classifiers=160, negative_classifiers=0
# sample 3411 is classified as 1, positive_classifiers=235, negative_classifiers=0
# sample 1300 is classified as 0, positive_classifiers=0, negative_classifiers=19
# sample 3197 is classified as 1, positive_classifiers=25, negative_classifiers=0
# sample 975 is classified as 1, positive_classifiers=243, negative_classifiers=0
# sample 3970 is classified as 1, positive_classifiers=25, negative_classifiers=0
# sample 2516 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2338 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 3988 is classified as 0, positive_classifiers=0, negative_classifiers=19
# sample 327 is classified as 1, positive_classifiers=271, negative_classifiers=0
# sample 711 is classified as 1, positive_classifiers=215, negative_classifiers=0
# sample 4055 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 1216 is classified as 1, positive_classifiers=17, negative_classifiers=0
# sample 1746 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2154 is classified as 1, positive_classifiers=70, negative_classifiers=0
# sample 2350 is classified as 1, positive_classifiers=33, negative_classifiers=6
# sample 1877 is classified as 0, positive_classifiers=0, negative_classifiers=10
# sample 3129 is classified as 0, positive_classifiers=0, negative_classifiers=111
# sample 1907 is classified as 0, positive_classifiers=0, negative_classifiers=14
# sample 2300 is classified as 1, positive_classifiers=18, negative_classifiers=0
# sample 3198 is classified as 1, positive_classifiers=6, negative_classifiers=0
# sample 2248 is classified as 1, positive_classifiers=78, negative_classifiers=0
# sample 4258 is classified as 1, positive_classifiers=114, negative_classifiers=0
# sample 3350 is classified as 1, positive_classifiers=103, negative_classifiers=5
# sample 3654 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 225 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 451 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4167 is classified as 0, positive_classifiers=0, negative_classifiers=41
# sample 162 is classified as 1, positive_classifiers=25, negative_classifiers=0
# sample 1859 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 532 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 531 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3519 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2358 is classified as 1, positive_classifiers=277, negative_classifiers=0
# sample 4289 is classified as 1, positive_classifiers=95, negative_classifiers=0
# sample 1291 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2812 is classified as 1, positive_classifiers=19, negative_classifiers=3
# sample 1357 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4279 is classified as 0, positive_classifiers=0, negative_classifiers=87
# sample 1359 is classified as 0, positive_classifiers=0, negative_classifiers=166
# sample 2858 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3419 is classified as 0, positive_classifiers=0, negative_classifiers=4
# sample 203 is classified as 0, positive_classifiers=0, negative_classifiers=2
# sample 1811 is classified as 1, positive_classifiers=6, negative_classifiers=4
# sample 3038 is classified as 0, positive_classifiers=0, negative_classifiers=111
# sample 262 is classified as 1, positive_classifiers=133, negative_classifiers=0
# sample 378 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3747 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2252 is classified as 1, positive_classifiers=24, negative_classifiers=0
# sample 3255 is classified as 0, positive_classifiers=0, negative_classifiers=100
# sample 589 is classified as 1, positive_classifiers=161, negative_classifiers=0
# sample 3437 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2755 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4249 is classified as 1, positive_classifiers=11, negative_classifiers=5
# sample 1953 is classified as 0, positive_classifiers=0, negative_classifiers=79
# sample 314 is classified as 1, positive_classifiers=6, negative_classifiers=2
# sample 2874 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2532 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 4098 is classified as 1, positive_classifiers=54, negative_classifiers=0
# sample 620 is classified as 1, positive_classifiers=212, negative_classifiers=0
# sample 3427 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1651 is classified as 1, positive_classifiers=36, negative_classifiers=2
# sample 4045 is classified as 0, positive_classifiers=0, negative_classifiers=102
# sample 738 is classified as 1, positive_classifiers=217, negative_classifiers=0
# sample 708 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3588 is classified as 0, positive_classifiers=0, negative_classifiers=12
# sample 66 is classified as 1, positive_classifiers=7, negative_classifiers=0
# sample 407 is classified as 0, positive_classifiers=0, negative_classifiers=279
# sample 1491 is classified as 1, positive_classifiers=8, negative_classifiers=0
# sample 1478 is classified as 1, positive_classifiers=280, negative_classifiers=0
# sample 2439 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3180 is classified as 1, positive_classifiers=245, negative_classifiers=0
# sample 1320 is classified as 0, positive_classifiers=0, negative_classifiers=111
# sample 3354 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2490 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2793 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3989 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2553 is classified as 1, positive_classifiers=8, negative_classifiers=0
# sample 1912 is classified as 1, positive_classifiers=313, negative_classifiers=0
# sample 3836 is classified as 1, positive_classifiers=70, negative_classifiers=0
# sample 3289 is classified as 1, positive_classifiers=18, negative_classifiers=0
# sample 2600 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3903 is classified as 0, positive_classifiers=0, negative_classifiers=22
# sample 274 is classified as 1, positive_classifiers=13, negative_classifiers=0
# sample 4073 is classified as 0, positive_classifiers=0, negative_classifiers=21
# sample 68 is classified as 0, positive_classifiers=0, negative_classifiers=165
# sample 3946 is classified as 0, positive_classifiers=0, negative_classifiers=107
# sample 3150 is classified as 0, positive_classifiers=0, negative_classifiers=7
# sample 1367 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1997 is classified as 1, positive_classifiers=17, negative_classifiers=0
# sample 2752 is classified as 1, positive_classifiers=24, negative_classifiers=0
# sample 4269 is classified as 1, positive_classifiers=11, negative_classifiers=5
# sample 3659 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2099 is classified as 0, positive_classifiers=0, negative_classifiers=77
# sample 2666 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4097 is classified as 1, positive_classifiers=69, negative_classifiers=0
# sample 1280 is classified as 1, positive_classifiers=45, negative_classifiers=0
# sample 446 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2090 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 917 is classified as 1, positive_classifiers=334, negative_classifiers=0
# sample 4165 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 2342 is classified as 0, positive_classifiers=0, negative_classifiers=63
# sample 697 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 989 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4185 is classified as 0, positive_classifiers=0, negative_classifiers=20
# sample 2538 is classified as 1, positive_classifiers=111, negative_classifiers=0
# sample 1474 is classified as 1, positive_classifiers=180, negative_classifiers=0
# sample 930 is classified as 1, positive_classifiers=110, negative_classifiers=0
# sample 1901 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4231 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 408 is classified as 0, positive_classifiers=0, negative_classifiers=106
# sample 2232 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 724 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2304 is classified as 0, positive_classifiers=0, negative_classifiers=154
# sample 4085 is classified as 0, positive_classifiers=0, negative_classifiers=3
# sample 2482 is classified as 1, positive_classifiers=290, negative_classifiers=0
# sample 651 is classified as 0, positive_classifiers=0, negative_classifiers=12
# sample 3060 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 1946 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2940 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1391 is classified as 1, positive_classifiers=52, negative_classifiers=0
# sample 2730 is classified as 0, positive_classifiers=0, negative_classifiers=127
# sample 1509 is classified as 1, positive_classifiers=3, negative_classifiers=0
# sample 213 is classified as 1, positive_classifiers=65, negative_classifiers=0
# sample 3442 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3285 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 638 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3368 is classified as 0, positive_classifiers=0, negative_classifiers=100
# sample 3570 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2043 is classified as 0, positive_classifiers=0, negative_classifiers=70
# sample 395 is classified as 0, positive_classifiers=0, negative_classifiers=14
# sample 1589 is classified as 1, positive_classifiers=3, negative_classifiers=0
# sample 1452 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4234 is classified as 1, positive_classifiers=64, negative_classifiers=0
# sample 1483 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 489 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4221 is classified as 1, positive_classifiers=271, negative_classifiers=0
# sample 4130 is classified as 0, positive_classifiers=0, negative_classifiers=279
# sample 2970 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2742 is classified as 1, positive_classifiers=43, negative_classifiers=0
# sample 3798 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1175 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 248 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3898 is classified as 0, positive_classifiers=0, negative_classifiers=99
# sample 153 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3202 is classified as 1, positive_classifiers=36, negative_classifiers=0
# sample 3031 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 401 is classified as 0, positive_classifiers=0, negative_classifiers=35
# sample 3656 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1678 is classified as 0, positive_classifiers=0, negative_classifiers=73
# sample 61 is classified as 0, positive_classifiers=0, negative_classifiers=10
# sample 4175 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2892 is classified as 1, positive_classifiers=35, negative_classifiers=15
# sample 3773 is classified as 0, positive_classifiers=0, negative_classifiers=33
# sample 3335 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2175 is classified as 1, positive_classifiers=30, negative_classifiers=16
# sample 758 is classified as 1, positive_classifiers=193, negative_classifiers=0
# sample 3241 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 655 is classified as 1, positive_classifiers=4, negative_classifiers=2
# sample 1296 is classified as 0, positive_classifiers=0, negative_classifiers=20
# sample 1110 is classified as 0, positive_classifiers=0, negative_classifiers=166
# sample 4331 is classified as 1, positive_classifiers=7, negative_classifiers=0
# sample 1186 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1872 is classified as 1, positive_classifiers=245, negative_classifiers=0
# sample 118 is classified as 1, positive_classifiers=47, negative_classifiers=5
# sample 438 is classified as 0, positive_classifiers=0, negative_classifiers=43
# sample 2478 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 311 is classified as 0, positive_classifiers=0, negative_classifiers=24
# sample 1089 is classified as 0, positive_classifiers=0, negative_classifiers=7
# sample 3057 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 313 is classified as 0, positive_classifiers=0, negative_classifiers=14
# sample 2796 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4336 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 627 is classified as 1, positive_classifiers=161, negative_classifiers=0
# sample 1955 is classified as 1, positive_classifiers=19, negative_classifiers=0
# sample 1010 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1225 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3015 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1520 is classified as 1, positive_classifiers=63, negative_classifiers=0
# sample 4199 is classified as 1, positive_classifiers=23, negative_classifiers=0
# sample 4306 is classified as 0, positive_classifiers=0, negative_classifiers=61
# sample 2835 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1586 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2311 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2810 is classified as 0, positive_classifiers=0, negative_classifiers=70
# sample 1348 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3870 is classified as 1, positive_classifiers=6, negative_classifiers=0
# sample 1950 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4052 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2902 is classified as 0, positive_classifiers=0, negative_classifiers=29
# sample 2589 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3677 is classified as 0, positive_classifiers=0, negative_classifiers=1
# sample 4069 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2900 is classified as 0, positive_classifiers=0, negative_classifiers=35
# sample 3518 is classified as 1, positive_classifiers=81, negative_classifiers=0
# sample 3590 is classified as 1, positive_classifiers=3, negative_classifiers=0
# sample 2285 is classified as 0, positive_classifiers=0, negative_classifiers=61
# sample 3311 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3334 is classified as 0, positive_classifiers=0, negative_classifiers=44
# sample 2245 is classified as 1, positive_classifiers=43, negative_classifiers=0
# sample 1006 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 677 is classified as 0, positive_classifiers=0, negative_classifiers=153
# sample 3556 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2103 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 897 is classified as 1, positive_classifiers=35, negative_classifiers=0
# sample 2385 is classified as 0, positive_classifiers=0, negative_classifiers=79
# sample 134 is classified as 1, positive_classifiers=47, negative_classifiers=0
# sample 2229 is classified as 1, positive_classifiers=313, negative_classifiers=0
# sample 1809 is classified as 1, positive_classifiers=13, negative_classifiers=0
# sample 1929 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1940 is classified as 0, positive_classifiers=0, negative_classifiers=279
# sample 3610 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 693 is classified as 1, positive_classifiers=27, negative_classifiers=0
# sample 3716 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1073 is classified as 1, positive_classifiers=15, negative_classifiers=0
# sample 2111 is classified as 0, positive_classifiers=0, negative_classifiers=87
# sample 96 is classified as 1, positive_classifiers=110, negative_classifiers=0
# sample 973 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2888 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 287 is classified as 1, positive_classifiers=1, negative_classifiers=0
# sample 4030 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2466 is classified as 1, positive_classifiers=7, negative_classifiers=0
# sample 1606 is classified as 0, positive_classifiers=0, negative_classifiers=107
# sample 3322 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 515 is classified as 1, positive_classifiers=17, negative_classifiers=0
# sample 1727 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1316 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3735 is classified as 0, positive_classifiers=0, negative_classifiers=39
# sample 3753 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 370 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1157 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3620 is classified as 0, positive_classifiers=0, negative_classifiers=84
# sample 490 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4271 is classified as 1, positive_classifiers=10, negative_classifiers=0
# sample 1230 is classified as 0, positive_classifiers=0, negative_classifiers=148
# sample 3036 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4082 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 2011 is classified as 0, positive_classifiers=0, negative_classifiers=96
# sample 1179 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2920 is classified as 1, positive_classifiers=52, negative_classifiers=0
# sample 2863 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3452 is classified as 0, positive_classifiers=0, negative_classifiers=22
# sample 1562 is classified as 0, positive_classifiers=0, negative_classifiers=158
# sample 3720 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4322 is classified as 1, positive_classifiers=5, negative_classifiers=0
# sample 1229 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3890 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3885 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 4252 is classified as 1, positive_classifiers=25, negative_classifiers=0
# sample 1965 is classified as 1, positive_classifiers=24, negative_classifiers=19
# sample 3632 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 2325 is classified as 0, positive_classifiers=0, negative_classifiers=3
# sample 774 is classified as 1, positive_classifiers=27, negative_classifiers=0
# sample 1003 is classified as 0, positive_classifiers=0, negative_classifiers=153
# sample 4220 is classified as 1, positive_classifiers=36, negative_classifiers=13
# sample 2875 is classified as 1, positive_classifiers=271, negative_classifiers=0
# sample 339 is classified as 1, positive_classifiers=24, negative_classifiers=0
# sample 1707 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 650 is classified as 1, positive_classifiers=50, negative_classifiers=0
# sample 54 is classified as 1, positive_classifiers=321, negative_classifiers=0
# sample 3436 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3821 is classified as 1, positive_classifiers=31, negative_classifiers=0
# sample 755 is classified as 1, positive_classifiers=189, negative_classifiers=0
# sample 3389 is classified as 0, positive_classifiers=0, negative_classifiers=84
# sample 3713 is classified as 1, positive_classifiers=161, negative_classifiers=0
# sample 2460 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3529 is classified as 1, positive_classifiers=21, negative_classifiers=0
# sample 1584 is classified as 0, positive_classifiers=0, negative_classifiers=37
# sample 1273 is classified as 0, positive_classifiers=0, negative_classifiers=1
# sample 2128 is classified as 0, positive_classifiers=0, negative_classifiers=50
# sample 1489 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3370 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3943 is classified as 0, positive_classifiers=0, negative_classifiers=279
# sample 794 is classified as 1, positive_classifiers=17, negative_classifiers=0
# sample 680 is classified as 1, positive_classifiers=49, negative_classifiers=3
# sample 2818 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1934 is classified as 0, positive_classifiers=0, negative_classifiers=3
# sample 4157 is classified as 1, positive_classifiers=103, negative_classifiers=0
# sample 1060 is classified as 1, positive_classifiers=38, negative_classifiers=0
# sample 3230 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2495 is classified as 0, positive_classifiers=0, negative_classifiers=58
# ...
# sample 2451 is classified as 1, positive_classifiers=277, negative_classifiers=0
# sample 3262 is classified as 0, positive_classifiers=0, negative_classifiers=70
# sample 2966 is classified as 0, positive_classifiers=0, negative_classifiers=2
# sample 1869 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4075 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3565 is classified as 1, positive_classifiers=3, negative_classifiers=2
# sample 137 is classified as 0, positive_classifiers=0, negative_classifiers=44
# sample 219 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 30 is classified as 1, positive_classifiers=141, negative_classifiers=0
# sample 1682 is classified as 1, positive_classifiers=18, negative_classifiers=0
# sample 3815 is classified as 0, positive_classifiers=0, negative_classifiers=1
# sample 2677 is classified as 0, positive_classifiers=0, negative_classifiers=10
# sample 1127 is classified as 0, positive_classifiers=0, negative_classifiers=16
# sample 2993 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1058 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 848 is classified as 0, positive_classifiers=0, negative_classifiers=70
# sample 1386 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2186 is classified as 1, positive_classifiers=77, negative_classifiers=0
# sample 2811 is classified as 1, positive_classifiers=106, negative_classifiers=0
# sample 268 is classified as 0, positive_classifiers=0, negative_classifiers=69
# sample 108 is classified as 1, positive_classifiers=5, negative_classifiers=0
# sample 2794 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2455 is classified as 1, positive_classifiers=12, negative_classifiers=0
# sample 2525 is classified as 0, positive_classifiers=0, negative_classifiers=165
# sample 106 is classified as 1, positive_classifiers=80, negative_classifiers=0
# sample 4207 is classified as 0, positive_classifiers=0, negative_classifiers=57
# sample 4264 is classified as 1, positive_classifiers=133, negative_classifiers=0
# sample 1016 is classified as 0, positive_classifiers=0, negative_classifiers=39
# sample 1815 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3948 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1424 is classified as 0, positive_classifiers=0, negative_classifiers=70
# sample 4067 is classified as 1, positive_classifiers=349, negative_classifiers=0
# sample 191 is classified as 1, positive_classifiers=98, negative_classifiers=0
# sample 4024 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4002 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1868 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3094 is classified as 1, positive_classifiers=98, negative_classifiers=0
# sample 3802 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 323 is classified as 1, positive_classifiers=29, negative_classifiers=4
# sample 2800 is classified as 1, positive_classifiers=35, negative_classifiers=0
# sample 915 is classified as 1, positive_classifiers=161, negative_classifiers=0
# sample 3314 is classified as 0, positive_classifiers=0, negative_classifiers=166
# sample 1690 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2607 is classified as 1, positive_classifiers=6, negative_classifiers=0
# sample 2134 is classified as 0, positive_classifiers=0, negative_classifiers=10
# sample 3026 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1112 is classified as 1, positive_classifiers=271, negative_classifiers=0
# sample 3240 is classified as 0, positive_classifiers=0, negative_classifiers=100
# sample 1346 is classified as 0, positive_classifiers=0, negative_classifiers=12
# sample 497 is classified as 1, positive_classifiers=132, negative_classifiers=0
# sample 1193 is classified as 0, positive_classifiers=0, negative_classifiers=70
# sample 2746 is classified as 0, positive_classifiers=0, negative_classifiers=75
# sample 750 is classified as 1, positive_classifiers=63, negative_classifiers=0
# sample 49 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4110 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 71 is classified as 1, positive_classifiers=70, negative_classifiers=0
# sample 2660 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2453 is classified as 0, positive_classifiers=0, negative_classifiers=157
# sample 4214 is classified as 1, positive_classifiers=17, negative_classifiers=0
# sample 387 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3873 is classified as 1, positive_classifiers=201, negative_classifiers=0
# sample 421 is classified as 1, positive_classifiers=228, negative_classifiers=0
# sample 752 is classified as 1, positive_classifiers=4, negative_classifiers=0
# sample 3580 is classified as 0, positive_classifiers=0, negative_classifiers=4
# sample 2831 is classified as 0, positive_classifiers=0, negative_classifiers=11
# sample 2699 is classified as 1, positive_classifiers=245, negative_classifiers=0
# sample 2021 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2645 is classified as 0, positive_classifiers=0, negative_classifiers=35
# sample 4291 is classified as 0, positive_classifiers=0, negative_classifiers=16
# sample 1757 is classified as 0, positive_classifiers=0, negative_classifiers=3
# sample 746 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 4277 is classified as 0, positive_classifiers=0, negative_classifiers=41
# sample 866 is classified as 1, positive_classifiers=25, negative_classifiers=0
# sample 3349 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1533 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2277 is classified as 1, positive_classifiers=4, negative_classifiers=0
# sample 630 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2611 is classified as 0, positive_classifiers=0, negative_classifiers=243
# sample 3358 is classified as 1, positive_classifiers=232, negative_classifiers=0
# sample 1430 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1303 is classified as 1, positive_classifiers=290, negative_classifiers=0
# sample 1146 is classified as 1, positive_classifiers=133, negative_classifiers=0
# sample 1783 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3919 is classified as 0, positive_classifiers=0, negative_classifiers=39
# sample 2051 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 303 is classified as 0, positive_classifiers=0, negative_classifiers=76
# sample 1148 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 3964 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3633 is classified as 0, positive_classifiers=0, negative_classifiers=11
# sample 299 is classified as 1, positive_classifiers=302, negative_classifiers=0
# sample 4272 is classified as 1, positive_classifiers=25, negative_classifiers=0
# sample 2981 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3468 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2061 is classified as 1, positive_classifiers=46, negative_classifiers=0
# sample 1943 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 802 is classified as 0, positive_classifiers=0, negative_classifiers=8
# sample 2144 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3697 is classified as 0, positive_classifiers=0, negative_classifiers=77
# sample 2365 is classified as 1, positive_classifiers=5, negative_classifiers=0
# sample 2174 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1981 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 797 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3795 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 925 is classified as 1, positive_classifiers=43, negative_classifiers=0
# sample 271 is classified as 0, positive_classifiers=0, negative_classifiers=92
# sample 2547 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 825 is classified as 0, positive_classifiers=0, negative_classifiers=2
# sample 3592 is classified as 1, positive_classifiers=271, negative_classifiers=0
# sample 2992 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2006 is classified as 0, positive_classifiers=0, negative_classifiers=279
# sample 3854 is classified as 1, positive_classifiers=48, negative_classifiers=0
# sample 1377 is classified as 1, positive_classifiers=3, negative_classifiers=0
# sample 80 is classified as 0, positive_classifiers=0, negative_classifiers=100
# sample 852 is classified as 1, positive_classifiers=140, negative_classifiers=0
# sample 1475 is classified as 1, positive_classifiers=38, negative_classifiers=0
# sample 1203 is classified as 1, positive_classifiers=17, negative_classifiers=0
# sample 3465 is classified as 0, positive_classifiers=0, negative_classifiers=18
# sample 4000 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 257 is classified as 0, positive_classifiers=0, negative_classifiers=106
# sample 3331 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1702 is classified as 0, positive_classifiers=0, negative_classifiers=68
# sample 3362 is classified as 0, positive_classifiers=0, negative_classifiers=85
# sample 2251 is classified as 0, positive_classifiers=0, negative_classifiers=61
# sample 812 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2016 is classified as 1, positive_classifiers=42, negative_classifiers=0
# sample 843 is classified as 1, positive_classifiers=36, negative_classifiers=2
# sample 431 is classified as 1, positive_classifiers=57, negative_classifiers=0
# sample 2379 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3917 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 3940 is classified as 1, positive_classifiers=38, negative_classifiers=0
# sample 3390 is classified as 1, positive_classifiers=5, negative_classifiers=0
# sample 726 is classified as 0, positive_classifiers=0, negative_classifiers=127
# sample 1470 is classified as 1, positive_classifiers=54, negative_classifiers=0
# sample 3340 is classified as 1, positive_classifiers=111, negative_classifiers=0
# sample 4027 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1839 is classified as 1, positive_classifiers=43, negative_classifiers=0
# sample 3422 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3355 is classified as 0, positive_classifiers=0, negative_classifiers=2
# sample 3524 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4186 is classified as 1, positive_classifiers=167, negative_classifiers=0
# sample 1097 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2069 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3410 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 4253 is classified as 1, positive_classifiers=111, negative_classifiers=0
# sample 337 is classified as 0, positive_classifiers=0, negative_classifiers=64
# sample 2668 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1978 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 3543 is classified as 0, positive_classifiers=0, negative_classifiers=56
# sample 1515 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1151 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3377 is classified as 0, positive_classifiers=0, negative_classifiers=15
# sample 2442 is classified as 0, positive_classifiers=0, negative_classifiers=39
# sample 2211 is classified as 1, positive_classifiers=217, negative_classifiers=0
# sample 4036 is classified as 0, positive_classifiers=0, negative_classifiers=165
# sample 558 is classified as 1, positive_classifiers=43, negative_classifiers=0
# sample 3533 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1 is classified as 0, positive_classifiers=0, negative_classifiers=144
# sample 2000 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2313 is classified as 0, positive_classifiers=0, negative_classifiers=16
# sample 4206 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3399 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 295 is classified as 0, positive_classifiers=0, negative_classifiers=76
# sample 2893 is classified as 0, positive_classifiers=0, negative_classifiers=3
# sample 2475 is classified as 1, positive_classifiers=245, negative_classifiers=0
# sample 2059 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1618 is classified as 1, positive_classifiers=35, negative_classifiers=0
# sample 4120 is classified as 0, positive_classifiers=0, negative_classifiers=132
# sample 3000 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3139 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3397 is classified as 0, positive_classifiers=0, negative_classifiers=35
# sample 2481 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3010 is classified as 1, positive_classifiers=70, negative_classifiers=0
# sample 1892 is classified as 0, positive_classifiers=0, negative_classifiers=39
# sample 1454 is classified as 1, positive_classifiers=27, negative_classifiers=0
# sample 3067 is classified as 0, positive_classifiers=13, negative_classifiers=33
# sample 244 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2698 is classified as 0, positive_classifiers=0, negative_classifiers=165
# sample 1951 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3584 is classified as 0, positive_classifiers=0, negative_classifiers=106
# sample 1025 is classified as 0, positive_classifiers=0, negative_classifiers=22
# sample 966 is classified as 0, positive_classifiers=0, negative_classifiers=70
# sample 996 is classified as 0, positive_classifiers=0, negative_classifiers=57
# sample 2112 is classified as 0, positive_classifiers=0, negative_classifiers=279
# sample 1524 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 3084 is classified as 1, positive_classifiers=25, negative_classifiers=0
# sample 1764 is classified as 1, positive_classifiers=3, negative_classifiers=0
# sample 1831 is classified as 1, positive_classifiers=17, negative_classifiers=0
# sample 3837 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 2789 is classified as 0, positive_classifiers=0, negative_classifiers=279
# sample 1788 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 1574 is classified as 1, default, positive_classifiers=0, negative_classifiers=0
# sample 169 is classified as 1, positive_classifiers=1, negative_classifiers=0
# sample 3375 is classified as 1, default, positive_classifiers=0, negative_classifiers=0

# %%
#Metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification report:\n", classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7511520737327189
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.56      0.69       435
#            1       0.68      0.94      0.79       433
#
#     accuracy                           0.75       868
#    macro avg       0.79      0.75      0.74       868
# weighted avg       0.79      0.75      0.74       868
#
# Confusion matrix:
#  [[244 191]
#  [ 25 408]]

# %% [markdown]
# # 4. K Nearest Neighbor (KNN)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Configuring parameters for GridSearchCV
param_grid = {
    'n_neighbors': np.arange(1, 31),       # Number of neighbors
    'weights': ['uniform', 'distance'],   # Weights: uniform or weighted
    'metric': ['euclidean', 'manhattan']  # Distance metrics
}

# Model initialization
knn = KNeighborsClassifier()

# GridSearchCV initialization
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Model training and parameter selection
grid_search.fit(X_train, y_train)

# 8. GridSearchCV results
print("The best parametrs:", grid_search.best_params_)
print("Better accuracy on cross-validation:", grid_search.best_score_)

# Evaluation of the model with the best parameters
best_knn = grid_search.best_estimator_
y_pred = best_knn.predict(X_test)

# Metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification report:\n", classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# The best parametrs: {'metric': 'manhattan', 'n_neighbors': 27, 'weights': 'distance'}
# Better accuracy on cross-validation: 0.8384288764953455
# Accuracy: 0.8433179723502304
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84       435
#            1       0.84      0.84      0.84       433
#
#     accuracy                           0.84       868
#    macro avg       0.84      0.84      0.84       868
# weighted avg       0.84      0.84      0.84       868
#
# Confusion matrix:
#  [[368  67]
#  [ 69 364]]

# %% [markdown]
# # 5. Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB


# Model initialization
nb = GaussianNB()

# Model training
nb.fit(X_train, y_train)

# Predictions
y_pred = nb.predict(X_test)

# Metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification report:\n", classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.6117511520737328
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.96      0.71       435
#            1       0.88      0.26      0.40       433
#
#     accuracy                           0.61       868
#    macro avg       0.72      0.61      0.56       868
# weighted avg       0.72      0.61      0.56       868
#
# Confusion matrix:
#  [[419  16]
#  [321 112]]

# %% [markdown]
# # 6. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression


# Define parameter grid for GridSearchCV
param_grid = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],  # Regularization types
    'C': np.logspace(-4, 4, 20),                   # Inverse regularization strength
    'solver': ['lbfgs', 'liblinear', 'saga'],      # Solvers
    'max_iter': [100, 200, 300]                    # Number of iterations
}

# Initialize the model
log_reg = LogisticRegression()

# GridSearchCV initialization
grid_search = GridSearchCV(log_reg, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best model
best_log_reg = grid_search.best_estimator_

# Predictions
y_pred = best_log_reg.predict(X_test)

# Metrics
print("The best parameters:", grid_search.best_params_)
print("Better accuracy on cross-validation:", grid_search.best_score_)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification report:\n", classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# E:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 2100 fits failed out of a total of 3600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 300 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 300 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 300 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 75, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 300 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1182, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
# --------------------------------------------------------------------------------
# 227 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "E:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'elasticnet', 'l1'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 192 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "E:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l1', 'elasticnet', 'l2'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 278 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "E:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'l1', 'elasticnet'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 203 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "E:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "E:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'elasticnet', 'l1', 'l2'} or None. Got 'none' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan 0.50086414 0.49971223 0.79003255 0.79550391 0.79003255
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.50028777 0.79003255 0.79550391 0.79003255
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.50057637 0.79003255 0.79550391 0.79003255
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.4997114  0.7906085  0.79607945 0.7906085
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.50057637 0.7906085  0.79607945 0.7906085
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.50057637 0.7906085  0.79607945 0.7906085
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.5002886  0.79348952 0.79636971 0.79348952
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.5002886  0.79348952 0.79636971 0.79320134
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.4997114  0.79348952 0.79636971 0.79348952
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.5        0.7980984  0.80126635 0.7980984
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.5        0.7980984  0.80126635 0.7980984
#         nan        nan        nan        nan        nan        nan
#         nan 0.50086414 0.49942363 0.7980984  0.80126635 0.7980984
#         nan        nan        nan        nan        nan        nan
#         nan 0.79838824 0.74511102 0.81307445 0.80990732 0.81307445
#         nan        nan        nan        nan        nan        nan
#         nan 0.79838824 0.74511102 0.81307445 0.80990732 0.81307445
#         nan        nan        nan        nan        nan        nan
#         nan 0.79838824 0.74511102 0.81307445 0.80990732 0.81307445
#         nan        nan        nan        nan        nan        nan
#         nan 0.80069081 0.79838824 0.83352145 0.83438434 0.83352145
#         nan        nan        nan        nan        nan        nan
#         nan 0.80069081 0.79838824 0.83352145 0.83438434 0.83352145
#         nan        nan        nan        nan        nan        nan
#         nan 0.80069081 0.79838824 0.83352145 0.83438434 0.83352145
#         nan        nan        nan        nan        nan        nan
#         nan 0.81509755 0.81509755 0.83928265 0.84043414 0.83899446
#         nan        nan        nan        nan        nan        nan
#         nan 0.81509755 0.81509755 0.83928265 0.84043414 0.83928265
#         nan        nan        nan        nan        nan        nan
#         nan 0.81509755 0.81509755 0.83928265 0.84043414 0.83928265
#         nan        nan        nan        nan        nan        nan
#         nan 0.84274335 0.84274335 0.84159186 0.84158937 0.84159186
#         nan        nan        nan        nan        nan        nan
#         nan 0.84274335 0.84274335 0.84159186 0.84158937 0.84159186
#         nan        nan        nan        nan        nan        nan
#         nan 0.84274335 0.84274335 0.84159186 0.84158937 0.84159186
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986358 0.83986358 0.84101632 0.84072855 0.84072855
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986358 0.83986358 0.84101632 0.84072855 0.84072855
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986358 0.83986358 0.84101632 0.84072855 0.84072855
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986482 0.83986482 0.84332096 0.84332096 0.84360915
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986482 0.83986482 0.84332096 0.84332096 0.84360915
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986482 0.83986482 0.84332096 0.84332096 0.84360915
#         nan        nan        nan        nan        nan        nan
#         nan 0.84015176 0.84015176 0.83928762 0.83986399 0.84043995
#         nan        nan        nan        nan        nan        nan
#         nan 0.84015176 0.84015176 0.83928762 0.83986399 0.84043995
#         nan        nan        nan        nan        nan        nan
#         nan 0.84015176 0.84015176 0.83928762 0.83986399 0.84043995
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986399 0.83986399 0.83928762 0.83899985 0.83928762
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986399 0.83986399 0.83928762 0.83899985 0.83928762
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986399 0.83986399 0.83928762 0.83899985 0.83928762
#         nan        nan        nan        nan        nan        nan
#         nan 0.83928804 0.83928804 0.83957622 0.83957622 0.83957622
#         nan        nan        nan        nan        nan        nan
#         nan 0.83928804 0.83928804 0.83957622 0.83957622 0.83957622
#         nan        nan        nan        nan        nan        nan
#         nan 0.83928804 0.83928804 0.83957622 0.83957622 0.83957622
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84015259 0.84015259 0.84015259
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84015259 0.84015259 0.84015259
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84015259 0.84015259 0.84015259
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84015259 0.83986441 0.84015259
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84015259 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84015259 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.83957622 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.83957622 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.83957622 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.83957622 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.83957622 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.83957622 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.83928804 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.83928804 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.83928804 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84072813 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84072813 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84072813 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84015176 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84015176 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan
#         nan 0.83986441 0.83986441 0.84015176 0.83986441 0.83986441
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# The best parameters: {'C': 0.615848211066026, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# Better accuracy on cross-validation: 0.8436091472643211
# Accuracy: 0.8179723502304147
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81       435
#            1       0.80      0.84      0.82       433
#
#     accuracy                           0.82       868
#    macro avg       0.82      0.82      0.82       868
# weighted avg       0.82      0.82      0.82       868
#
# Confusion matrix:
#  [[345  90]
#  [ 68 365]]

# %% [markdown]
# # 7. SVM

# %%
from sklearn.svm import SVC


# Define parameter grid for GridSearchCV
param_grid = {
    'C': np.logspace(-3, 3, 10),         # Regularization parameter
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],  # Kernel types
    'gamma': ['scale', 'auto'],          # Kernel coefficient for 'rbf', 'poly', and 'sigmoid'
    'degree': [2, 3, 4],                 # Degree for 'poly' kernel
    'class_weight': [None, 'balanced']   # Handles class imbalance
}

# Initialize the model
svm = SVC()

# GridSearchCV initialization
grid_search = GridSearchCV(svm, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best model
best_svm = grid_search.best_estimator_

# Predictions
y_pred = best_svm.predict(X_test)

# Metrics
print("The best parameters:", grid_search.best_params_)
print("Better accuracy on cross-validation:", grid_search.best_score_)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification report:\n", classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# The best parameters: {'C': 46.41588833612773, 'class_weight': None, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# Better accuracy on cross-validation: 0.8617544005141708
# Accuracy: 0.826036866359447
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82       435
#            1       0.81      0.86      0.83       433
#
#     accuracy                           0.83       868
#    macro avg       0.83      0.83      0.83       868
# weighted avg       0.83      0.83      0.83       868
#
# Confusion matrix:
#  [[346  89]
#  [ 62 371]]

# %% [markdown]
# # 8. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier


# Define parameter grid for GridSearchCV
param_grid = {
    'criterion': ['gini', 'entropy', 'log_loss'],  # Splitting criteria
    'max_depth': [None, 5, 10, 20, 50],           # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],              # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 5, 10],            # Minimum number of samples required to be at a leaf node
    'class_weight': [None, 'balanced']            # Handles class imbalance
}

# Initialize the model
dt = DecisionTreeClassifier()

# GridSearchCV initialization
grid_search = GridSearchCV(dt, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best model
best_dt = grid_search.best_estimator_

# Predictions
y_pred = best_dt.predict(X_test)

# Metrics
print("The best parameters:", grid_search.best_params_)
print("Better accuracy on cross-validation:", grid_search.best_score_)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification report:\n", classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# The best parameters: {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Better accuracy on cross-validation: 0.8519627640826819
# Accuracy: 0.826036866359447
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82       435
#            1       0.80      0.87      0.83       433
#
#     accuracy                           0.83       868
#    macro avg       0.83      0.83      0.83       868
# weighted avg       0.83      0.83      0.83       868
#
# Confusion matrix:
#  [[341  94]
#  [ 57 376]]

# %% [markdown]
# # 9. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier


# Define parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200, 500],          # Number of trees in the forest
    'criterion': ['gini', 'entropy', 'log_loss'], # Splitting criteria
    'max_depth': [None, 10, 20, 50],              # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],              # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 5, 10],            # Minimum number of samples required to be at a leaf node
    'class_weight': [None, 'balanced']            # Handles class imbalance
}

# Initialize the model
rf = RandomForestClassifier()

# GridSearchCV initialization
grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best model
best_rf = grid_search.best_estimator_

# Predictions
y_pred = best_rf.predict(X_test)

# Metrics
print("The best parameters:", grid_search.best_params_)
print("Better accuracy on cross-validation:", grid_search.best_score_)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification report:\n", classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# The best parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 500}
# Better accuracy on cross-validation: 0.8608886032384466
# Accuracy: 0.8329493087557603
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       435
#            1       0.81      0.87      0.84       433
#
#     accuracy                           0.83       868
#    macro avg       0.83      0.83      0.83       868
# weighted avg       0.83      0.83      0.83       868
#
# Confusion matrix:
#  [[348  87]
#  [ 58 375]]

# %% [markdown]
# # 10. XGBoost

# %%
from xgboost import XGBClassifier


# Замените < и другие символы в столбцах на more_than_
X_train.columns = X_train.columns.str.replace(r'<', 'less_than_', regex=True)
X_test.columns = X_test.columns.str.replace(r'<', 'less_than_', regex=True)

X_train.columns = X_train.columns.str.replace(r'>', 'more_than_', regex=True)
X_test.columns = X_test.columns.str.replace(r'>', 'more_than_', regex=True)

y_train = y_train.astype('bool')
y_test = y_test.astype('bool')

# Определение параметров для GridSearchCV с умеренным количеством значений
param_grid = {
    'n_estimators': [100, 200, 500],  # Количество деревьев
    'learning_rate': [0.05, 0.1, 0.2],  # Шаг обучения
    'max_depth': [5, 7, 10],  # Глубина деревьев
    'subsample': [0.8, 1.0],  # Доля примеров для обучения каждого дерева
    'colsample_bytree': [0.8, 1.0],  # Доля признаков для обучения каждого дерева
    'gamma': [0, 0.1, 0.5],  # Минимальное уменьшение потерь для разделения
    'reg_alpha': [0, 0.1],  # Линейная регуляризация L1
    'reg_lambda': [1, 10],  # Линейная регуляризация L2
}

# Initialize the model
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# GridSearchCV initialization
grid_search = GridSearchCV(xgb, param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=1)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best model
best_xgb = grid_search.best_estimator_

# Predictions
y_pred = best_xgb.predict(X_test)

# Metrics
print("The best parameters for XGBoost:", grid_search.best_params_)
print("Better accuracy on cross-validation:", grid_search.best_score_)
print("Accuracy for XGBoost:", accuracy_score(y_test, y_pred))
print("Classification report for XGBoost:\n", classification_report(y_test, y_pred))
print("Confusion matrix for XGBoost:\n", confusion_matrix(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
# The best parameters for XGBoost: {'colsample_bytree': 0.8, 'gamma': 0.5, 'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# Better accuracy on cross-validation: 0.8637716915804532
# Accuracy for XGBoost: 0.8387096774193549
# Classification report for XGBoost:
#                precision    recall  f1-score   support
#
#        False       0.86      0.81      0.83       435
#         True       0.82      0.87      0.84       433
#
#     accuracy                           0.84       868
#    macro avg       0.84      0.84      0.84       868
# weighted avg       0.84      0.84      0.84       868
#
# Confusion matrix for XGBoost:
#  [[351  84]
#  [ 56 377]]
# E:\Anaconda\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:32:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
